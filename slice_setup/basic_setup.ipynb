# %%
# Import fablib library
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager()

# %%
# Create a slice
slice = fablib.new_slice(name="dh-aes-basic")

# %%
# Define sites
sites = {
    'server': 'SEAT',
    'switch': 'DALL',
    'clients': 'NEWY'
}

# Initialize dictionary to hold all nodes and their details
nodes = {}

# Add server
nodes['server'] = {
    'node': slice.add_node(name="server", site=sites['server'], cores=4, ram=8, disk=20, image='default_ubuntu_20'),
    'interfaces': []
}

# Add a client
nodes['station'] = {
    'node': slice.add_node(name="station", site=sites['clients'], cores=4, ram=8, disk=20, image='default_ubuntu_20'),
    'interfaces': []
}

# Add P4 switch
nodes['switch'] = {
    'node': slice.add_node(name="switch", site=sites['switch'], cores=32, ram=16, disk=40, image='default_ubuntu_20'),
    'interfaces': []
}

# %%
# Add network interfaces to each node
for name, node in nodes.items():
    num_interfaces = 2 if name == 'switch' else 1
    for i in range(num_interfaces):
        ifacename = 'net0' if name=='server' else ('net1' if name=='station' else f'net{i}')
        print(name, ifacename)
        interface = node['node'].add_component(name=ifacename, model='NIC_Basic').get_interfaces()[0]
        node['interfaces'].append(interface)
# Out:
# server net0
# station net1
# switch net0
# switch net1

# %%
# Setup networks between clients and switch
networks = {}
networks['net0'] = slice.add_l2network(name='net0', interfaces=[nodes['server']['interfaces'][0], nodes['switch']['interfaces'][0]])
networks['net1'] = slice.add_l2network(name='net1', interfaces=[nodes['station']['interfaces'][0], nodes['switch']['interfaces'][1]])

# %%
# Submit the slice
slice.submit()
# Out:
# Retry: 11, Time: 339 sec
# <style type="text/css">
# #T_ade4b tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ade4b tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ade4b caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_ade4b_row0_col0, #T_ade4b_row0_col1, #T_ade4b_row1_col0, #T_ade4b_row1_col1, #T_ade4b_row2_col0, #T_ade4b_row2_col1, #T_ade4b_row3_col0, #T_ade4b_row3_col1, #T_ade4b_row4_col0, #T_ade4b_row4_col1, #T_ade4b_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_ade4b_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_ade4b">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ade4b_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_ade4b_row0_col1" class="data row0 col1" >0321704f-25aa-4290-a56a-111af4488ea4</td>
#     </tr>
#     <tr>
#       <td id="T_ade4b_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_ade4b_row1_col1" class="data row1 col1" >dh-aes-basic</td>
#     </tr>
#     <tr>
#       <td id="T_ade4b_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_ade4b_row2_col1" class="data row2 col1" >2024-04-23 04:37:42 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ade4b_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_ade4b_row3_col1" class="data row3 col1" >2024-04-22 04:37:43 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ade4b_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_ade4b_row4_col1" class="data row4 col1" >6ce270de-788d-4e07-8bae-3206860a6387</td>
#     </tr>
#     <tr>
#       <td id="T_ade4b_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_ade4b_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_297b9 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_297b9 th {
#   text-align: left;
# }
# #T_297b9 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_297b9 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_297b9 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_297b9_row0_col0, #T_297b9_row0_col1, #T_297b9_row0_col2, #T_297b9_row0_col3, #T_297b9_row0_col4, #T_297b9_row0_col5, #T_297b9_row0_col6, #T_297b9_row0_col7, #T_297b9_row0_col8, #T_297b9_row0_col9, #T_297b9_row0_col10, #T_297b9_row0_col13, #T_297b9_row0_col14, #T_297b9_row0_col15, #T_297b9_row1_col0, #T_297b9_row1_col1, #T_297b9_row1_col
level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_7ab4d_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_7ab4d_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_7ab4d_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_7ab4d_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_7ab4d_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7ab4d_row0_col0" class="data row0 col0" >server-net0-p1</td>
#       <td id="T_7ab4d_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_7ab4d_row0_col2" class="data row0 col2" >server</td>
#       <td id="T_7ab4d_row0_col3" class="data row0 col3" >net0</td>
#       <td id="T_7ab4d_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_7ab4d_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_7ab4d_row0_col6" class="data row0 col6" ></td>
#       <td id="T_7ab4d_row0_col7" class="data row0 col7" >16:E2:69:28:D2:6E</td>
#       <td id="T_7ab4d_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_7ab4d_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_7ab4d_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_7ab4d_row0_col11" class="data row0 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_7ab4d_row1_col0" class="data row1 col0" >station-net1-p1</td>
#       <td id="T_7ab4d_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_7ab4d_row1_col2" class="data row1 col2" >station</td>
#       <td id="T_7ab4d_row1_col3" class="data row1 col3" >net1</td>
#       <td id="T_7ab4d_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_7ab4d_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_7ab4d_row1_col6" class="data row1 col6" ></td>
#       <td id="T_7ab4d_row1_col7" class="data row1 col7" >EE:97:25:8E:95:9F</td>
#       <td id="T_7ab4d_row1_col8" class="data row1 col8" >enp7s0</td>
#       <td id="T_7ab4d_row1_col9" class="data row1 col9" >enp7s0</td>
#       <td id="T_7ab4d_row1_col10" class="data row1 col10" >None</td>
#       <td id="T_7ab4d_row1_col11" class="data row1 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_7ab4d_row2_col0" class="data row2 col0" >switch-net1-p1</td>
#       <td id="T_7ab4d_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_7ab4d_row2_col2" class="data row2 col2" >switch</td>
#       <td id="T_7ab4d_row2_col3" class="data row2 col3" >net1</td>
#       <td id="T_7ab4d_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_7ab4d_row2_col5" class="data row2 col5" >config</td>
#       <td id="T_7ab4d_row2_col6" class="data row2 col6" ></td>
#       <td id="T_7ab4d_row2_col7" class="data row2 col7" >0E:0A:CD:51:48:0A</td>
#       <td id="T_7ab4d_row2_col8" class="data row2 col8" >enp8s0</td>
#       <td id="T_7ab4d_row2_col9" class="data row2 col9" >enp8s0</td>
#       <td id="T_7ab4d_row2_col10" class="data row2 col10" >None</td>
#       <td id="T_7ab4d_row2_col11" class="data row2 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_7ab4d_row3_col0" class="data row3 col0" >switch-net0-p1</td>
#       <td id="T_7ab4d_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_7ab4d_row3_col2" class="data row3 col2" >switch</td>
#       <td id="T_7ab4d_row3_col3" class="data row3 col3" >net0</td>
#       <td id="T_7ab4d_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_7ab4d_row3_col5" class="data row3 col5" >config</td>
#       <td id="T_7ab4d_row3_col6" class="data row3 col6" ></td>
#       <td id="T_7ab4d_row3_col7" class="data row3 col7" >0A:E8:BC:38:6C:84</td>
#       <td id="T_7ab4d_row3_col8" class="data row3 col8" >enp7s0</td>
#       <td id="T_7ab4d_row3_col9" class="data row3 col9" >enp7s0</td>
#       <td id="T_7ab4d_row3_col10" class="data row3 col10" >None</td>
#       <td id="T_7ab4d_row3_col11" class="data row3 col11" >6</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 346 seconds
# '0321704f-25aa-4290-a56a-111af4488ea4'

# %%
import pandas as pd

slice = fablib.get_slice('dh-aes-basic')
pd.set_option('display.max_colwidth', None)
slice_info = [{'Name': n.get_name(), 'SSH command': n.get_ssh_command()} for n in slice.get_nodes()]
pd.DataFrame(slice_info).set_index('Name')
# Out:
#                                                                                                                                           SSH command
# Name
# server   ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3080:f816:3eff:fe2d:1df2
# station  ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3080:f816:3eff:fe97:345e
# switch   ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3000:f816:3eff:fed3:fd23
